# %% [markdown]
# # Day -1 This the 1st Day of Data Analyst

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(2+3)
# Out:
# 5

# %% [markdown]
# # Python Comments
# ### A) Single Line comment
# ### B) Multi Line comment

# %%
#This is a comments
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World") # This is also a comment
# Out:
# Hello World

# %%
"""this is a multi Line Comment"""

#This 
#is also
#a multi line comment
# Out:
# 'this is a multi Line Comment'
